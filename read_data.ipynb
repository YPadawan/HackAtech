# %%
import pandas as pd

# %%
df = pd.read_csv("./core_angles-core_hand-90s.csv")

# %%
df.head()
# Out:
#    Channel_1  Channel_2  Channel_3  Channel_4  Channel_5  Channel_6  \
# 0         66        169        336        106         60         36
# 1         62        174        382        136         65         35
# 2         66        155        355        148         67         36
# 3         66        147        349        150         69         35
# 4         64        124        322        142         57         30
#
#    Channel_7  Channel_8  Thumb_TMC_fe  Thumb_tmc_aa  ...  Index_pip  \
# 0         52        177     -0.426721     -0.357426  ...   0.525832
# 1         53        194     -0.366869     -0.388312  ...   0.499922
# 2         59        213     -0.354629     -0.375564  ...   0.460743
# 3         51        185     -0.357055     -0.363991  ...   0.446436
# 4         45        147     -0.366679     -0.336791  ...   0.454109
#
#    Middle_mcp_fe  Middle_mcp_aa  Middle_pip  Ring_mcp_fe  Ring_mcp_aa  \
# 0      -0.244179       0.032966    0.549186    -0.060919     0.056198
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4486 entries, 0 to 4485
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Channel_1      4486 non-null   int64
#  1   Channel_2      4486 non-null   int64
#  2   Channel_3      4486 non-null   int64
#  3   Channel_4      4486 non-null   int64
#  4   Channel_5      4486 non-null   int64
#  5   Channel_6      4486 non-null   int64
#  6   Channel_7      4486 non-null   int64
#  7   Channel_8      4486 non-null   int64
#  8   Thumb_TMC_fe   4486 non-null   float64
#  9   Thumb_tmc_aa   4486 non-null   float64
#  10  Thumb_mcp_fe   4486 non-null   float64
#  11  Thumb_mcp_aa   4486 non-null   float64
#  12  Index_mcp_fe   4486 non-null   float64
#  13  Index_mcp_aa   4486 non-null   float64
#  14  Index_pip      4486 non-null   float64
#  15  Middle_mcp_fe  4486 non-null   float64
#  16  Middle_mcp_aa  4486 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Channel_1', 'Channel_2', 'Channel_3', 'Channel_4', 'Channel_5',
#        'Channel_6', 'Channel_7', 'Channel_8', 'Thumb_TMC_fe', 'Thumb_tmc_aa',
#        'Thumb_mcp_fe', 'Thumb_mcp_aa', 'Index_mcp_fe', 'Index_mcp_aa',
#        'Index_pip', 'Middle_mcp_fe', 'Middle_mcp_aa', 'Middle_pip',
#        'Ring_mcp_fe', 'Ring_mcp_aa', 'Ring_pip', 'Little_mcp_fe',
#        'Little_mcp_aa', 'Little_pip'],
#       dtype='object')
